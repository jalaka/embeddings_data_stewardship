# %%
import boto3
from io import BytesIO
import gzip
import tempfile

# %%
#init spark
# Import the findspark module 
import findspark
import os
# Initialize via the full spark path
findspark.init("/opt/apache-spark")
# Import the SparkSession and SQLContext modules
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext

# Build the SparkSession
spark = SparkSession.builder \
   .master("local[12]") \
   .appName("CommonCrawl") \
   .config("spark.executor.memory", "1gb") \
   .getOrCreate()
spark.conf.set("spark.sql.debug.maxToStringFields", 1000)
# Main entry point for Spark functionality. A SparkContext represents the
# connection to a Spark cluster, and can be used to create :class:`RDD` and
# broadcast variables on that cluster.      
sc = spark.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/30 15:06:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Path to the folder containing the CSV files
csv_folder_path = "combined_domains_cc"

# Read all CSV files in the folder
df = spark.read.option("header", "true").csv(os.path.join(csv_folder_path, "*.csv"))

# %%
from pyspark.sql.types import *

bhSchema = StructType([
    StructField("_id", StringType(), True),
    StructField("_index", StringType(), True),
    StructField("author", StringType(), True),
    StructField("category", ArrayType(StringType()), True),
    StructField("checked", BooleanType(), True),
    StructField("confirmed", BooleanType(), True),
    StructField("content", StringType(), True),
    StructField("content_origin", StringType(), True),
    StructField("content_raw", StringType(), True),
    StructField("datasource", StringType(), True),
    StructField("date", TimestampType(), True),
    StructField("date_entry", TimestampType(), True),
    StructField("domain", StringType(), True),
    StructField("keywords", ArrayType(StringType()), True),
    StructField("language", StringType(), True),
    StructField("language_origin", StringType(), True),
    StructField("latitude", DoubleType(), True),
    StructField("location", StringType(), True),
    StructField("longitude", DoubleType(), True),
    StructField("source", StringType(), True),
    StructField("submitted_by", StringType(), True),
    StructField("subtitle", StringType(), True),
    StructField("subtitle_origin", StringType(), True),
    StructField("summary", StringType(), True),
    StructField("title", StringType(), True),
    StructField("title_origin", StringType(), True),
    StructField("translated", BooleanType(), True),
    StructField("updated_by", StringType(), True)
])

# %%
# Load the JSON file into a DataFrame using the defined schema
dfBH = spark.read.schema(bhSchema).json("../export_osdp_2024-04-25_07-58-58_1.json", multiLine=True)
# Show the DataFrame
dfBH.show(5)

# Print the schema
df.printSchema()
dfBH.printSchema()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +--------------------+------+--------------------+---------+-------+---------+--------------------+--------------------+-----------+----------+-------------------+-------------------+-----------------+--------------------+--------+---------------+--------+--------+---------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+----------+
# |                 _id|_index|              author| category|checked|confirmed|             content|      content_origin|content_raw|datasource|               date|         date_entry|           domain|            keywords|language|language_origin|latitude|location|longitude|              source|submitted_by|            subtitle|     subtitle_origin|             summary|               title|        title_origin|translated|updated_by|
# +--------------------+------+--------------------+---------+-------+---------+--------------------+--------------------+-----------+----------+-------------------+-------------------+-----------------+--------------------+--------+---------------+--------+--------+---------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+----------+
# |38039205-f367-447...|  osdp|     Autor ungenannt|[krimisi]|   true|    false|<p>The soldiers o...|<p>Die Soldaten d...|           |          |2024-04-20 02:00:00|2024-04-25 09:54:22|www.bundesheer.at|[Struktur, Strukt...|      en|             de|     0.0|        |      0.0|https://www.bunde...|      cdfz02|                    |                    |                    |AIR LANDINGS: SOL...|LUFTLANDUNGEN: SO...|      true|          |
# |3cdc9f81-df65-4f8...|  osdp|       Samantha Reed|  [cyber]|   true|    false|<p>A recent discl...|<p>A recent discl...|           |          |2024-04-24 02:00:00|2024-04-25 09:54:01|    newslinker.co|[Struktur, Strukt...|      en|             en|     0.0|        |      0.0|https://newslinke...|     cdizg01|Zero-day vulnerab...|Zero-day vulnerab...|                    |CrushFTP Servers ...|CrushFTP Servers ...|     false|          |
# |8ac107ac-611b-4d2...|  osdp|     Autor ungenannt|[krimisi]|   true|    false|<p>Ukraine lacks ...|<p>Ukraine lacks ...|       null|          |2024-04-25 02:00:00|2024-04-25 09:52:41|  www.rnbo.gov.ua|[Struktur, Strukt...|      en|             en|     0.0|        |      0.0|https://www.rnbo....|      cdfz01|                    |                    |National Security...|Oleksandr Lytvyne...|Oleksandr Lytvyne...|     false|          |
# |510378dc-99b6-4a5...|  osdp|Christian Mölling...|[krimisi]|   true|    false|<p>In the past we...|<p>Die <a href="h...|           |          |2024-04-25 02:00:00|2024-04-25 09:52:27|       www.zdf.de|[Struktur, Strukt...|      en|             de|     0.0|        |      0.0|https://www.zdf.d...|      cdfz02|While Ukraine spe...|Während die Ukrai...|                    |Ukraine between a...|Ukraine zwischen ...|      true|          |
# |e9e0a5d0-2928-44b...|  osdp|     Autor ungenannt|[krimisi]|   true|    false|<p>On Wednesday 2...|<p>Le mouvement p...|       null|          |2024-04-25 02:00:00|2024-04-25 09:52:14|www.liberation.fr|[Struktur, Strukt...|      en|             fr|     0.0|        |      0.0|https://www.liber...|      cdfz08|                    |                    |Sur sa chaîne Tel...|Israel: Hamas rel...|Attaque du 7 octo...|      true|          |
# +--------------------+------+--------------------+---------+-------+---------+--------------------+--------------------+-----------+----------+-------------------+-------------------+-----------------+--------------------+--------+---------------+--------+--------+---------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+----------+
# only showing top 5 rows
#
# root
#  |-- MetaData: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- mime: string (nullable = true)
#  |-- mime-detected: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- digest: string (nullable = true)
#  |-- length: string (nullable = true)
#  |-- offset: string (nullable = true)
#  |-- filename: string (nullable = true)
#  |-- charset: string (nullable = true)
#  |-- languages: string (nullable = true)
#  |-- TLD: string (nullable = true)
#  |-- Domain: string (nullable = true)
#  |-- Path: string (nullable = true)
#
# root
#  |-- _id: string (nullable = true)
#  |-- _index: string (nullable = true)
#  |-- author: string (nullable = true)
#  |-- category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- checked: boolean (nullable = true)
#  |-- confirmed: boolean (nullable = true)
#  |-- content: string (nullable = true)
#  |-- content_origin: string (nullable = true)
#  |-- content_raw: string (nullable = true)
#  |-- datasource: string (nullable = true)
#  |-- date: timestamp (nullable = true)
#  |-- date_entry: timestamp (nullable = true)
#  |-- domain: string (nullable = true)
#  |-- keywords: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- language: string (nullable = true)
#  |-- language_origin: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- location: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- source: string (nullable = true)
#  |-- submitted_by: string (nullable = true)
#  |-- subtitle: string (nullable = true)
#  |-- subtitle_origin: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- title_origin: string (nullable = true)
#  |-- translated: boolean (nullable = true)
#  |-- updated_by: string (nullable = true)

# %%
from urllib.parse import urlparse, urlunparse, quote, unquote, parse_qsl, urlencode
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
def normalize_url(url):
    # Parse the URL into components
    parsed_url = urlparse(url)
    
    # Convert scheme and host to lowercase
    scheme = parsed_url.scheme.lower()
    host = parsed_url.hostname.lower() if parsed_url.hostname else ''
    
    # Remove default port
    port = parsed_url.port
    if (scheme == 'http' and port == 80) or (scheme == 'https' and port == 443):
        port = None
    
    # Normalize path
    path = quote(unquote(parsed_url.path))
    segments = path.split('/')
    resolved_segments = []
    for segment in segments:
        if segment == '..':
            if resolved_segments:
                resolved_segments.pop()
        elif segment and segment != '.':
            resolved_segments.append(segment)
    normalized_path = '/' + '/'.join(resolved_segments)
    
    # Ensure trailing slash for directory paths
    if normalized_path[-1] != '/' and not normalized_path.split('/')[-1].count('.'):
        normalized_path += '/'
    
    # Sort query parameters
    query = urlencode(sorted(parse_qsl(parsed_url.query)))
    
    # Reconstruct the URL without fragment
    normalized_url = urlunparse((scheme, f"{host}:{port}" if port else host, normalized_path, '', query, ''))
    
    return normalized_url
normalize_url_udf = udf(normalize_url, StringType())

# %%
df_normalized_cc = df.withColumn("normalized_url", normalize_url_udf(df["url"]))
df_normalized_bh = dfBH.withColumn("normalized_url", normalize_url_udf(dfBH["source"]))
for col_name in df_normalized_cc.columns:
    df_normalized_cc = df_normalized_cc.withColumnRenamed(col_name, f"CC_{col_name}")

# Rename all columns in df2
for col_name in df_normalized_bh.columns:
    df_normalized_bh = df_normalized_bh.withColumnRenamed(col_name, f"BH_{col_name}")

# %%
# Perform the join operation to find overlaps
overlap_df = df_normalized_cc.join(df_normalized_bh, df_normalized_cc["CC_url"]==df_normalized_bh["BH_source"] ,"inner")

# Show the overlapping URLs
overlap_df.show(1)

# Count the number of overlapping URLs
overlap_count = overlap_df.count()
print(f"Number of overlapping URLs: {overlap_count}")
# Out:
# +--------------------+--------------------+--------------------+---------+----------------+---------+--------------------+---------+---------+--------------------+----------+------------+------+----------+--------------------+--------------------+--------------------+---------+---------------+-----------+----------+------------+--------------------+--------------------+--------------+-------------+-------------------+-------------------+----------+--------------------+-----------+------------------+-----------+-----------+------------+--------------------+---------------+-----------+------------------+--------------------+--------------------+--------------------+-------------+-------------+--------------------+
# |         CC_MetaData|             CC_Date|              CC_url|  CC_mime|CC_mime-detected|CC_status|           CC_digest|CC_length|CC_offset|         CC_filename|CC_charset|CC_languages|CC_TLD| CC_Domain|             CC_Path|   CC_normalized_url|              BH__id|BH__index|      BH_author|BH_category|BH_checked|BH_confirmed|          BH_content|   BH_content_origin|BH_content_raw|BH_datasource|            BH_date|      BH_date_entry| BH_domain|         BH_keywords|BH_language|BH_language_origin|BH_latitude|BH_location|BH_longitude|           BH_source|BH_submitted_by|BH_subtitle|BH_subtitle_origin|          BH_summary|            BH_title|     BH_title_origin|BH_translated|BH_updated_by|   BH_normalized_url|
# +--------------------+--------------------+--------------------+---------+----------------+---------+--------------------+---------+---------+--------------------+----------+------------+------+----------+--------------------+--------------------+--------------------+---------+---------------+-----------+----------+------------+--------------------+--------------------+--------------+-------------+-------------------+-------------------+----------+--------------------+-----------+------------------+-----------+-----------+------------+--------------------+---------------+-----------+------------------+--------------------+--------------------+--------------------+-------------+-------------+--------------------+
# |com,alghad)/secti...|2024-07-19T14:35:...|https://alghad.co...|text/html|       text/html|      200|3ZBTE4UZH4UKUAAHF...|    22158| 80122194|crawl-data/CC-MAI...|     UTF-8|         ara|   com|alghad.com|/section-106/%d8%...|https://alghad.co...|644ef584-e515-49a...|     osdp|Autor ungenannt|  [krimisi]|      true|        true|<p></p><p>Israeli...|<p></p><p><strong...|          null|             |2024-04-11 15:47:25|2024-04-12 10:20:20|alghad.com|[Struktur, Strukt...|         en|                ar|        0.0|           |         0.0|https://alghad.co...|      bentaiebz|           |                  |شنت القوات الإسرا...|Israeli occupatio...|جيش الاحتلال الإس...|         true|             |https://alghad.co...|
# +--------------------+--------------------+--------------------+---------+----------------+---------+--------------------+---------+---------+--------------------+----------+------------+------+----------+--------------------+--------------------+--------------------+---------+---------------+-----------+----------+------------+--------------------+--------------------+--------------+-------------+-------------------+-------------------+----------+--------------------+-----------+------------------+-----------+-----------+------------+--------------------+---------------+-----------+------------------+--------------------+--------------------+--------------------+-------------+-------------+--------------------+
# only showing top 1 row
# [Stage 8:>                                                          (0 + 1) / 1]
# Number of overlapping URLs: 393

# %%
# get all entries in the scoped common crawl that have the same url in the bh dataset
cc_wo_overlap = df_normalized_cc.join(df_normalized_bh, df_normalized_cc["CC_url"]==df_normalized_bh["BH_source"], how="left_anti")

# %%
overlap_df.printSchema()
# Out:
# root
#  |-- CC_MetaData: string (nullable = true)
#  |-- CC_Date: string (nullable = true)
#  |-- CC_url: string (nullable = true)
#  |-- CC_mime: string (nullable = true)
#  |-- CC_mime-detected: string (nullable = true)
#  |-- CC_status: string (nullable = true)
#  |-- CC_digest: string (nullable = true)
#  |-- CC_length: string (nullable = true)
#  |-- CC_offset: string (nullable = true)
#  |-- CC_filename: string (nullable = true)
#  |-- CC_charset: string (nullable = true)
#  |-- CC_languages: string (nullable = true)
#  |-- CC_TLD: string (nullable = true)
#  |-- CC_Domain: string (nullable = true)
#  |-- CC_Path: string (nullable = true)
#  |-- CC_normalized_url: string (nullable = true)
#  |-- BH__id: string (nullable = true)
#  |-- BH__index: string (nullable = true)
#  |-- BH_author: string (nullable = true)
#  |-- BH_category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- BH_checked: boolean (nullable = true)
#  |-- BH_confirmed: boolean (nullable = true)
#  |-- BH_content: string (nullable = true)
#  |-- BH_content_origin: string (nullable = true)
#  |-- BH_content_raw: string (nullable = true)
#  |-- BH_datasource: string (nullable = true)
#  |-- BH_date: timestamp (nullable = true)
#  |-- BH_date_entry: timestamp (nullable = true)
#  |-- BH_domain: string (nullable = true)
#  |-- BH_keywords: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- BH_language: string (nullable = true)
#  |-- BH_language_origin: string (nullable = true)
#  |-- BH_latitude: double (nullable = true)
#  |-- BH_location: string (nullable = true)
#  |-- BH_longitude: double (nullable = true)
#  |-- BH_source: string (nullable = true)
#  |-- BH_submitted_by: string (nullable = true)
#  |-- BH_subtitle: string (nullable = true)
#  |-- BH_subtitle_origin: string (nullable = true)
#  |-- BH_summary: string (nullable = true)
#  |-- BH_title: string (nullable = true)
#  |-- BH_title_origin: string (nullable = true)
#  |-- BH_translated: boolean (nullable = true)
#  |-- BH_updated_by: string (nullable = true)
#  |-- BH_normalized_url: string (nullable = true)

# %%
# Count unique domains of BH dataset that overlaps
unique_domains_count = overlap_df.select("CC_Domain").distinct().count()
print(f"Number of unique domains: {unique_domains_count}")

# Show the domains of BH dataset that overlaps
overlap_df.select("CC_Domain").distinct().show(truncate=False)

#overlap_df.show()
# Out:
# Number of unique domains: 23
# +------------------------+
# |CC_Domain               |
# +------------------------+
# |thehackernews.com       |
# |de.euronews.com         |
# |alghad.com              |
# |americanmilitarynews.com|
# |newatlas.com            |
# |sofrep.com              |
# |securityaffairs.com     |
# |defence-blog.com        |
# |securelist.com          |
# |scitechdaily.com        |
# |techxplore.com          |
# |kyivindependent.com     |
# |i-hls.com               |
# |addiyar.com             |
# |thecyberwire.com        |
# |bulgarianmilitary.com   |
# |thebarentsobserver.com  |
# |gbhackers.com           |
# |tass.com                |
# |cybernews.com           |
# +------------------------+
# only showing top 20 rows

# %%
# get all entries which url isn't in the bh dataaset but the domain is

# Get the distinct values from overlap_df
distinct_cc_domains = overlap_df.select("CC_Domain").distinct()
distinct_domains_list = [row["CC_Domain"] for row in distinct_cc_domains.collect()]

cc_irrelevant_same_domain = cc_wo_overlap.filter(cc_wo_overlap["CC_domain"].isin(distinct_domains_list))

# %%
# Get a random sample with a fixed seed
total_relevant_rows = overlap_df.count()
total_irrelvant_rows = cc_irrelevant_same_domain.count()
fraction = 2*(total_relevant_rows/(total_irrelvant_rows+total_relevant_rows))  # Fraction of rows to sample
# total number of irrelevant rows should be twice as big as relevant rows
seed = 1337  # Fixed seed for reproducibility

# %%
from pyspark.sql.functions import lit
selection_cols_BH = ["CC_normalized_url","CC_filename","BH_language_origin","BH_language","BH_keywords","BH_category"]
selection_cols_CC = ["CC_normalized_url","CC_filename"]
relevant_data = overlap_df.select(selection_cols_BH).withColumn("is_relevant", lit(True))
irrelevant_data = cc_irrelevant_same_domain.select(selection_cols_CC).sample(withReplacement=False, fraction=fraction, seed=seed).withColumn("is_relevant", lit(False))

cc_wo_overlap.select("CC_Domain").distinct().count()
# Out:
# 141

# %%
all_data = relevant_data.unionByName(irrelevant_data,allowMissingColumns=True)
all_data.count()
# Out:
# 1212

# %%
all_data.show(2000)
# Out:
# +--------------------+--------------------+------------------+-----------+--------------------+-------------------+-----------+
# |   CC_normalized_url|         CC_filename|BH_language_origin|BH_language|         BH_keywords|        BH_category|is_relevant|
# +--------------------+--------------------+------------------+-----------+--------------------+-------------------+-----------+
# |https://alghad.co...|crawl-data/CC-MAI...|                ar|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|  [cyber, innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://de.eurone...|crawl-data/CC-MAI...|                de|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Allgemeine Tags,...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://newslinke...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|   [cyber, krimisi]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|   [cyber, krimisi]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://techxplor...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://thecyberw...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thecyberw...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thecyberw...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://americanm...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|   [cyber, krimisi]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://i-hls.com...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|[krimisi, innotech]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|          [krimisi]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Auftragstags, Au...|  [cyber, innotech]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Auftragstags, Au...|  [cyber, innotech]|       true|
# |https://techxplor...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://thecyberw...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://alghad.co...|crawl-data/CC-MAI...|                ar|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|  [cyber, innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|   [cyber, krimisi]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://thecyberw...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://americanm...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|  [cyber, innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Cyber, Cyber\tBi...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybersecu...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://thecyberw...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thecyberw...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|         [innotech]|       true|
# |https://de.eurone...|crawl-data/CC-MAI...|                de|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://newslinke...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|   [cyber, krimisi]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://techxplor...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://newslinke...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://scitechda...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|         [innotech]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|   [cyber, krimisi]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://thecyberw...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://americanm...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|  [cyber, innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|  [cyber, innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|  [cyber, innotech]|       true|
# |https://de.eurone...|crawl-data/CC-MAI...|                de|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://thecyberw...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Cyber, Cyber\tCy...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://addiyar.c...|crawl-data/CC-MAI...|                ar|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://americanm...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybersecu...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|   [cyber, krimisi]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://newatlas....|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://sofrep.co...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|[krimisi, innotech]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|  [cyber, innotech]|       true|
# |https://technolog...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://techxplor...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://bulgarian...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://defence-b...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|          [krimisi]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://newslinke...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://securitya...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://tass.com/...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://thehacker...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|         [innotech]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://cybernews...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://de.eurone...|crawl-data/CC-MAI...|                de|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|  [cyber, innotech]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Allgemeine Tags,...|            [cyber]|       true|
# |https://gbhackers...|crawl-data/CC-MAI...|                en|         en|[Newsinfo, Newsin...|            [cyber]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# |https://kyivindep...|crawl-data/CC-MAI...|                en|         en|[Struktur, Strukt...|          [krimisi]|       true|
# ...
# |https://gbhackers...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://gbhackers...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thebarent...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://i-hls.com...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thebarent...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://addiyar.c...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://i-hls.com...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://gbhackers...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thebarent...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://i-hls.com...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://bulgarian...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://bulgarian...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://i-hls.com...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://tass.com/...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thebarent...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thebarent...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://i-hls.com...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://tass.com/...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://tass.com/...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://tass.com/...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://gbhackers...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://tass.com/...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://tass.com/...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://bulgarian...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://bulgarian...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://gbhackers...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://gbhackers...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://addiyar.c...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://gbhackers...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://bulgarian...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thebarent...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://tass.com/...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://bulgarian...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |http://tass.com/s...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://bulgarian...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thecyberw...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://bulgarian...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://gbhackers...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://cybernews...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://cybernews...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://cybernews...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://cybernews...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://cybernews...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://cybernews...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://cybernews...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://cybernews...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://cybersecu...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://technolog...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://technolog...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://newslinke...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://technolog...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://technolog...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://technolog...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://technolog...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://technolog...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# |https://thehacker...|crawl-data/CC-MAI...|              null|       null|                null|               null|      false|
# +--------------------+--------------------+------------------+-----------+--------------------+-------------------+-----------+

# %%
#count distinct number of warcs to download
distinct_count = all_data.select("CC_filename").distinct().count()
distinct_count
# Out:
# 1203

# %%
all_data.write.mode('overwrite').option("header", "true").json("target_data")
