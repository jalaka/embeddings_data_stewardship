# %%
# !pip install boto3 findspark py4j
# Out:
# Requirement already satisfied: boto3 in /home/jonas/.conda/envs/bachelor/lib/python3.12/site-packages (1.34.150)
# Requirement already satisfied: findspark in /home/jonas/.conda/envs/bachelor/lib/python3.12/site-packages (2.0.1)
# Requirement already satisfied: py4j in /home/jonas/.conda/envs/bachelor/lib/python3.12/site-packages (0.10.9.7)
# Requirement already satisfied: botocore<1.35.0,>=1.34.150 in /home/jonas/.conda/envs/bachelor/lib/python3.12/site-packages (from boto3) (1.34.150)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/jonas/.conda/envs/bachelor/lib/python3.12/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/jonas/.conda/envs/bachelor/lib/python3.12/site-packages (from boto3) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/jonas/.conda/envs/bachelor/lib/python3.12/site-packages (from botocore<1.35.0,>=1.34.150->boto3) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/jonas/.conda/envs/bachelor/lib/python3.12/site-packages (from botocore<1.35.0,>=1.34.150->boto3) (2.2.2)
# Requirement already satisfied: six>=1.5 in /home/jonas/.conda/envs/bachelor/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.150->boto3) (1.16.0)

# %%
import boto3
from io import BytesIO
import gzip
import tempfile

# %%
#init spark
# Import the findspark module 
import findspark
import os
# Initialize via the full spark path
findspark.init("/opt/apache-spark")
# Import the SparkSession and SQLContext modules
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext

# Build the SparkSession
spark = SparkSession.builder \
   .master("local[*]") \
   .appName("CommonCrawl") \
   .config("spark.executor.memory", "4gb") \
   .getOrCreate()
spark.conf.set("spark.sql.debug.maxToStringFields", 1000)
# Main entry point for Spark functionality. A SparkContext represents the
# connection to a Spark cluster, and can be used to create :class:`RDD` and
# broadcast variables on that cluster.      
sc = spark.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/07/31 11:05:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import os
import boto3
from io import BytesIO
import gzip
import requests

def get_s3_file_content(bucket, dataset, key, data_dir='data'):
    # Ensure the data directory exists
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
    
    # Define the local path for the file
    local_path = os.path.join(data_dir, key.replace('/', '_'))
    
    # Function to download and uncompress the file
    def download_and_uncompress_file():
        # Initialize S3 client
        s3 = boto3.client('s3')
        
        # Get the compressed file from S3
        compressed_file = BytesIO(s3.get_object(Bucket=bucket, Key=key)['Body'].read())
        
        # Uncompress the file
        uncompressed_file = gzip.GzipFile(None, 'rb', fileobj=compressed_file).read()
        
        # Save the uncompressed file locally
        with open(local_path, 'wb') as f:
            f.write(uncompressed_file)
        
        return uncompressed_file
    
        # Function to download and uncompress the file
    def download_and_uncompress_file_noaws():
        # Construct the URL
        url = f"https://data.commoncrawl.org/{key}"
        
        # Download the file
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes
        
        # Get the compressed file from the response
        compressed_file = BytesIO(response.content)

        if ".gz" in key:
            # Uncompress the file
            uncompressed_file = gzip.GzipFile(None, 'rb', fileobj=compressed_file).read()
        else:
            uncompressed_file = compressed_file.read()
        
        # Save the uncompressed file locally
        with open(local_path, 'wb') as f:
            f.write(uncompressed_file)
        
        return uncompressed_file
    
    # Check if file exists locally
    if os.path.exists(local_path):
        print(f"File {local_path} already exists. Loading it.")
        with open(local_path, 'rb') as f:
            file_content = f.read()
    else:
        print(f"File {local_path} does not exist. Downloading it from Common Crawl.")
        file_content = download_and_uncompress_file_noaws()
    
    return file_content

def download_s3_file(bucket, dataset, key, data_dir='data'):
    # Ensure the data directory exists
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
    
    # Define the local path for the file
    local_path = os.path.join(data_dir, key.replace('/', '_'))
    
    # Function to download and uncompress the file
    def download_and_uncompress_file():
        # Initialize S3 client
        s3 = boto3.client('s3')
        
        # Get the compressed file from S3
        compressed_file = BytesIO(s3.get_object(Bucket=bucket, Key=key)['Body'].read())
        
        # Uncompress the file
        uncompressed_file = gzip.GzipFile(None, 'rb', fileobj=compressed_file).read()
        
        # Save the uncompressed file locally
        with open(local_path, 'wb') as f:
            f.write(uncompressed_file)
        
        return uncompressed_file
    
        # Function to download and uncompress the file
    def download_and_uncompress_file_noaws():
        # Construct the URL
        url = f"https://data.commoncrawl.org/{key}"
        
        # Download the file
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes
        
        # Get the compressed file from the response
        compressed_file = BytesIO(response.content)

        if ".gz" in key:
            # Uncompress the file
            uncompressed_file = gzip.GzipFile(None, 'rb', fileobj=compressed_file).read()
        else:
            uncompressed_file = compressed_file.read()
        
        # Save the uncompressed file locally
        with open(local_path, 'wb') as f:
            f.write(uncompressed_file)
        
        return uncompressed_file
    
    # Check if file exists locally
    if os.path.exists(local_path) or os.path.exists(local_path[:-3]):
        print(f"File {local_path} already exists. Loading it.")
    else:
        print(f"File {local_path} does not exist. Downloading it from Common Crawl.")
        download_and_uncompress_file_noaws()
    
    return local_path

# %%
bucket = "commoncrawl"
dataset = "CC-MAIN-2024-30"
key = f"crawl-data/{dataset}/cc-index.paths.gz"
content = get_s3_file_content(bucket, dataset, key)
# Out:
# File data/crawl-data_CC-MAIN-2024-30_cc-index.paths.gz already exists. Loading it.

# %%
files = content.decode("ascii").split("\n")
cluster_idx = [file for file in files if "cluster.idx" in file][0]

# %%
# get index file
key = cluster_idx
index_file = get_s3_file_content(bucket, dataset, key).decode("ascii").split("\n")
# Out:
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cluster.idx already exists. Loading it.

# %%
key = f"crawl-data/{dataset}/cc-index-table.paths.gz"
files = get_s3_file_content(bucket, dataset, key).decode("ascii").split("\n")
cluster_paths = [file for file in files]
# Out:
# File data/crawl-data_CC-MAIN-2024-30_cc-index-table.paths.gz already exists. Loading it.

# %%
#find relevant index files

# get at domains
at_files = [x for x in index_file if x.startswith("com")]

# get index paths

index_files =  set([x.split("\t")[1] for x in at_files ])

index_keys = [f"cc-index/collections/{dataset}/indexes/{x}" for x in index_files]

#domains = set([".".join(x.split(")")[0].split(",")[::-1]) for x in at_files])
print(index_keys)
# Out:
# ['cc-index/collections/CC-MAIN-2024-30/indexes/cdx-
gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00128.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00131.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00131.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00111.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00111.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00091.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00091.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00053.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00053.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00085.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00085.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00027.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00027.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00064.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00064.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00037.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00037.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00139.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00139.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00046.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00046.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00052.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00052.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00121.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00121.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00156.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00156.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00034.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00034.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00063.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00063.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00055.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00055.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00076.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00076.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00058.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00058.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00130.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00130.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00086.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00086.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00040.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00040.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00062.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00062.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00126.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00126.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00049.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00049.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00122.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00122.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00068.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00068.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00074.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00074.gz already exists. Loading it.
# Downloading: cc-index/collections/CC-MAIN-2024-30/indexes/cdx-00094.gz
# File data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00094.gz already exists. Loading it.

# %%
"""
import shutil
import gzip
import json
import re
pattern = r'[^/]+(?=\.gz)'
for i,x in enumerate(index_filenames):
    print(i)
    match = re.search(pattern, x)
    ex = match.group()
    with gzip.open(index_filenames[i], 'rb') as s_file, open(f"data/{ex}.index", 'wb') as d_file:
        print(s_file,d_file)
        shutil.copyfileobj(s_file, d_file, 65536)
        os.unlink(index_filenames[i])
"""
# Out:
# 0
# <gzip _io.BufferedReader name='data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00104.gz' 0x786d0afdfca0> <_io.BufferedWriter name='data/cc-index_collections_CC-MAIN-2024-30_indexes_cdx-00104.index'>
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# Cell In[16], line 12
#      10 with gzip.open(index_filenames[i], 'rb') as s_file, open(f"data/{ex}.index", 'wb') as d_file:
#      11     print(s_file,d_file)
# ---> 12     shutil.copyfileobj(s_file, d_file, 65536)
#      13     os.unlink(index_filenames[i])
#
# File ~/.conda/envs/bachelor/lib/python3.12/shutil.py:203, in copyfileobj(fsrc, fdst, length)
#     201 fsrc_read = fsrc.read
#     202 fdst_write = fdst.write
# --> 203 while buf := fsrc_read(length):
#     204     fdst_write(buf)
#
# File ~/.conda/envs/bachelor/lib/python3.12/gzip.py:324, in GzipFile.read(self, size)
#     322     import errno
#     323     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 324 return self._buffer.read(size)
#
# File ~/.conda/envs/bachelor/lib/python3.12/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~/.conda/envs/bachelor/lib/python3.12/gzip.py:527, in _GzipReader.read(self, size)
#     523 if self._new_member:
#     524     # If the _new_member flag is set, we have to
#     525     # jump to the next member, if there is one.
#     526     self._init_read()
# --> 527     if not self._read_gzip_header():
#     528         self._size = self._pos
#     529         return b""
#
# File ~/.conda/envs/bachelor/lib/python3.12/gzip.py:496, in _GzipReader._read_gzip_header(self)
#     495 def _read_gzip_header(self):
# --> 496     last_mtime = _read_gzip_header(self._fp)
#     497     if last_mtime is None:
#     498         return False
#
# File ~/.conda/envs/bachelor/lib/python3.12/gzip.py:456, in _read_gzip_header(fp)
#     453     return None
#     455 if magic != b'\037\213':
# --> 456     raise BadGzipFile('Not a gzipped file (%r)' % magic)
#     458 (method, flag, last_mtime) = struct.unpack("<BBIxx", _read_exact(fp, 8))
#     459 if method != 8:
#
# BadGzipFile: Not a gzipped file (b'co')

# %%
for filename in index_filenames:
    # Define the new filename without the .gz extension
    if os.path.exists(filename):
        new_filename = filename[:-3]
        
        # Rename the file
        os.rename(filename, new_filename)
